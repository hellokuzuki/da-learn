# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %config Completer.use_jedi=False

# %% [markdown]
# ## Basic plotting: plot

# %%
ts = pd.Series(np.random.randn(1000), index = pd.date_range('1/1/2021', periods=1000))
print(ts)
print(ts.cumsum())
ts = ts.cumsum()
# Out:
# 2021-01-01    0.488238
# 2021-01-02   -0.641024
# 2021-01-03    0.278768
# 2021-01-04   -1.065512
# 2021-01-05   -0.514716
#                 ...
# 2023-09-23   -1.471675
# 2023-09-24    0.039216
# 2023-09-25    0.768427
# 2023-09-26   -0.041692
# 2023-09-27    1.395607
# Freq: D, Length: 1000, dtype: float64
# 2021-01-01     0.488238
# 2021-01-02    -0.152786
# 2021-01-03     0.125983
# 2021-01-04    -0.939529
# 2021-01-05    -1.454245
#                 ...
# 2023-09-23   -37.302930
# 2023-09-24   -37.263714
# 2023-09-25   -36.495288
# 2023-09-26   -36.536980
# 2023-09-27   -35.141373
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2021-01-01  0.872473 -0.353401 -1.205333  0.206584
# 2021-01-02  0.949104 -0.095731 -0.277309  0.828938
# 2021-01-03  1.076004 -0.080096  0.615016 -0.646531
# 2021-01-04 -1.946268 -0.677284  0.899228 -0.829103
# 2021-01-05 -0.092048 -1.214850 -0.682055  0.720112
# ...              ...       ...       ...       ...
# 2023-09-23  1.215307 -0.167393  0.142203 -0.600229
# 2023-09-24  0.055152 -0.235042  0.122590  1.627450
# 2023-09-25 -0.065778 -0.179390  0.580344 -0.387121
# 2023-09-26  0.197930 -0.150850  0.349251 -0.608724
# 2023-09-27  1.234656 -2.980943 -1.006014  0.308020
#
# [1000 rows x 4 columns]

# %%
df = df.cumsum()
plt.figure()
df.plot()
# Out:
# <AxesSubplot:>

# %%
df3 = pd.DataFrame(np.random.randn(1000, 2), index=pd.date_range('1/1/2020', periods=1000), columns=['B', 'C']).cumsum()
df3
# Out:
#                    B          C
# 2020-01-01 -0.618883  -0.652443
# 2020-01-02 -1.379122  -0.277118
# 2020-01-03 -1.296132  -2.514250
# 2020-01-04 -1.667580  -2.649506
# 2020-01-05 -1.150553  -0.857251
# ...              ...        ...
# 2022-09-22 -0.661061 -21.943013
# 2022-09-23 -2.225802 -21.503755
# 2022-09-24 -0.196235 -22.650835
# 2022-09-25 -1.292747 -23.039242
# 2022-09-26 -2.612624 -23.386717
#
# [1000 rows x 2 columns]

# %%
df3["A"] = pd.Series(list(range(len(df))))
df3["A"]
# df3.plot(x='A', y='B')
# Out:
# 2020-01-01   NaN
# 2020-01-02   NaN
# 2020-01-03   NaN
# 2020-01-04   NaN
# 2020-01-05   NaN
#               ..
# 2022-09-22   NaN
# 2022-09-23   NaN
# 2022-09-24   NaN
# 2022-09-25   NaN
# 2022-09-26   NaN
# Freq: D, Name: A, Length: 1000, dtype: float64

# %%
df3['A'] = pd.Series(list(range(len(df))), index=df3.index)
df3.plot(x='A', y='B')
# Out:
# <AxesSubplot:xlabel='A'>

# %% [markdown]
# ## Other plots
# ---

# %%
plt.figure()
df.iloc[5].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
dir(df.plot)
# Out:
# ['__annotations__',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_accessors',
#  '_all_kinds',
#  '_common_kinds',
#  '_constructor',
#  '_dataframe_kinds',
#  '_deprecations',
#  '_dir_additions',
#  '_dir_deletions',
#  '_get_call_args',
#  '_kind_aliases',
#  '_reset_cache',
#  '_series_kinds',
#  'area',
#  'bar',
#  'barh',
#  'box',
#  'density',
#  'hexbin',
#  'hist',
#  'kde',
#  'line',
#  'pie',
#  'scatter']

# %% [markdown]
# ## Bar plots
# ---

# %%
df.iloc[5].plot.bar();
plt.axhline(0, color='k')

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=list('ABCD'))
df2
# Out:
#           A         B         C         D
# 0  0.592269  0.685941  0.347206  0.998548
# 1  0.731155  0.101757  0.287516  0.484005
# 2  0.192646  0.750432  0.026631  0.730819
# 3  0.406371  0.621650  0.003063  0.841858
# 4  0.471061  0.450561  0.553319  0.851293
# 5  0.413148  0.085178  0.567504  0.437494
# 6  0.387775  0.960182  0.796555  0.240497
# 7  0.399658  0.529505  0.609487  0.488478
# 8  0.600546  0.733290  0.341403  0.299133
# 9  0.692056  0.720502  0.638044  0.066504

# %%
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df2.plot.barh(stacked=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Histograms
# ---

# %%
df4 = pd.DataFrame(
        {
            "a": np.random.randn(1000) + 1,
            "b": np.random.randn(1000),
            "c": np.random.randn(1000) - 1,
        },
        columns=["a", "b", "c"],
    )
df4
# Out:
#             a         b         c
# 0    2.163728  1.725300 -1.025457
# 1    1.040544  0.891318 -0.163064
# 2    1.444497  0.501727 -3.162104
# 3   -0.266525 -0.895232 -0.900916
# 4    3.071049 -2.301685 -2.647182
# ..        ...       ...       ...
# 995  2.604371  0.593721 -0.677005
# 996 -1.067113  1.246181  0.137814
# 997  1.910906 -1.668874  0.299193
# 998  0.827889 -0.014547 -0.938286
# 999  0.677611  0.002504 -1.021085
#
# [1000 rows x 3 columns]

# %%
df4.plot.hist(alpha=0.5)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df4.plot.hist(stacked=True, bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df4["a"].plot.hist(orientation="horizontal", cumulative=True);

# %%
df["A"].diff().hist();

# %%
df.diff().hist(color="k", alpha=0.5, bins=50);

# %% [markdown]
# ## Box plot
# ---

# %%
df = pd.DataFrame(np.random.rand(10, 5), columns=["A", "B", "C", "D", "E"])
df
# Out:
#           A         B         C         D         E
# 0  0.778615  0.042568  0.405271  0.423704  0.852343
# 1  0.123307  0.817300  0.919394  0.823211  0.605356
# 2  0.867399  0.298046  0.501381  0.004524  0.280967
# 3  0.180315  0.055247  0.903850  0.703615  0.063784
# 4  0.713097  0.239702  0.066626  0.128782  0.951296
# 5  0.676953  0.739118  0.066468  0.879065  0.288620
# 6  0.675059  0.446683  0.389554  0.187909  0.747801
# 7  0.964615  0.757018  0.351109  0.497355  0.972163
# 8  0.230791  0.823257  0.963862  0.258004  0.947816
# 9  0.200477  0.235302  0.807202  0.533332  0.114521

# %%
df.plot.box();

# %% [markdown]
# ## Area plot
# ---

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=["a", "b", "c", "d"])
df.plot.area()
# Out:
# <AxesSubplot:>

# %%
df.plot.area(stacked=False);

# %% [markdown]
# ## Scatter plot
# ---

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=["a", "b", "c", "d"])
df.plot.scatter(x="a", y="b");

# %%
ax = df.plot.scatter(x="a", y="b", color="DarkBlue", label="Group 1")
df.plot.scatter(x="c", y="d", color="DarkGreen", label="Group 2", ax=ax);

# %%
df.plot.scatter(x="a", y="b", c="c", s=50);

# %%
df.plot.scatter(x="a", y="b", s=df["c"] * 200);

# %% [markdown]
# ## Hexagonal bin plot
# ---

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=["a", "b"])
df["b"] = df["b"] + np.arange(1000)
df
# Out:
#             a           b
# 0    0.484467   -0.965704
# 1    1.875479    2.145959
# 2    0.021016    4.502171
# 3   -0.123664    4.956662
# 4   -0.476925    5.353590
# ..        ...         ...
# 995 -0.332298  995.962275
# 996  1.319546  997.945071
# 997  0.153965  995.632639
# 998 -0.630408  997.572382
# 999  0.653635  998.682201
#
# [1000 rows x 2 columns]

# %%
df.plot.hexbin(x="a", y="b", gridsize=25);

# %% [markdown]
# ## Pie plot
# ---

# %%
series = pd.Series(3 * np.random.rand(4), index=["a", "b", "c", "d"], name="series")
series
# Out:
# a    1.976456
# b    1.752256
# c    2.022415
# d    1.504226
# Name: series, dtype: float64

# %%
series.plot.pie(figsize=(6, 6));

# %% [markdown]
# ## Plotting with missing data
# ---
# If any of these defaults are not what you want, or if you want to be explicit about how missing values are handled, consider using fillna() or dropna() before plotting.

# %% [markdown]
# ## Plotting tools
# ---

# %% [markdown]
# ### Scatter matrix plot
# ---

# %%
 from pandas.plotting import scatter_matrix
df = pd.DataFrame(np.random.randn(1000, 4), columns=["a", "b", "c", "d"])
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal="kde");

# %% [markdown]
# ## Density plot
# ---

# %%
ser = pd.Series(np.random.randn(1000))
ser.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## Andrews curves
# ---

# %%
from pandas.plotting import andrews_curves
data = pd.read_csv('https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv')
plt.figure()
andrews_curves(data, "species")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Parallel coordinates
# ---

# %%
from pandas.plotting import parallel_coordinates
data = pd.read_csv('https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv')
plt.figure()
parallel_coordinates(data, "species")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Lag plot
# ---

# %%
from pandas.plotting import lag_plot
plt.figure();
spacing = np.linspace(-99 * np.pi, 99 * np.pi, num=1000)
data = pd.Series(0.1 * np.random.rand(1000) + 0.9 * np.sin(spacing))
data
# Out:
# 0      0.007213
# 1     -0.495973
# 2     -0.821971
# 3     -0.841854
# 4     -0.470237
#          ...
# 995    0.602451
# 996    0.883431
# 997    0.899206
# 998    0.622566
# 999    0.080887
# Length: 1000, dtype: float64

# %%
lag_plot(data);

# %% [markdown]
# ## Autocorrelation plot
# ---

# %%
from pandas.plotting import autocorrelation_plot
plt.figure();
spacing = np.linspace(-9 * np.pi, 9 * np.pi, num=1000)
data = pd.Series(0.7 * np.random.rand(1000) + 0.3 * np.sin(spacing))
autocorrelation_plot(data);

# %% [markdown]
# ## Bootstrap plot
# ---

# %%
from pandas.plotting import bootstrap_plot
data = pd.Series(np.random.rand(1000))
bootstrap_plot(data, size=50, samples=500, color="grey");

# %% [markdown]
# ## Plot formatting
# ---

# %% [markdown]
# ### General plot style arguments
# ---

# %%
plt.figure();
ts.plot(style="k--", label="Series");

# %% [markdown]
# ## Controlling the legend
# ---

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list("ABCD"))
df = df.cumsum()
df.plot(legend=False);
df.plot(legend=True);

# %% [markdown]
# ## Controlling the labels
# ---

# %%
df.plot()
df.plot(xlabel="new x", ylabel="new y");

# %% [markdown]
# ## Scales
# ---

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))
ts = np.exp(ts.cumsum())
ts.plot(logy=True);

# %% [markdown]
# ## Plotting on a secondary y-axis
# ---

# %%
df["A"].plot();
df["B"].plot(secondary_y=True, style="g");

# %%
plt.figure();
ax = df.plot(secondary_y=["A", "B"])
ax.set_ylabel("CD scale");
ax.right_ax.set_ylabel("AB scale");

# %% [markdown]
# ## Custom formatters for timeseries plots
# ---

# %% [markdown]
# ## Suppressing tick resolution adjustment
# ---

# %%
plt.figure();
df["A"].plot();

# %%
plt.figure();
df["A"].plot(x_compat=True);

# %%
plt.figure();
with pd.plotting.plot_params.use("x_compat", True):
    df["A"].plot(color="r")
    df["B"].plot(color="g")
    df["C"].plot(color="b")

# %% [markdown]
# ## Automatic date tick adjustment
# ### Subplots
# ---

# %%
df.plot(subplots=True, figsize=(6, 6));

# %% [markdown]
# ### Using layout and targeting multiple axes
# ---

# %%
df.plot(subplots=True, layout=(2, 3), figsize=(6, 6), sharex=False);

# %%
fig, axes = plt.subplots(4, 4, figsize=(9, 9))
plt.subplots_adjust(wspace=0.5, hspace=0.5)
target1 = [axes[0][0], axes[1][1], axes[2][2], axes[3][3]]
target2 = [axes[3][0], axes[2][1], axes[1][2], axes[0][3]]
df.plot(subplots=True, ax=target1, legend=False, sharex=False, sharey=False);
(-df).plot(subplots=True, ax=target2, legend=False, sharex=False, sharey=False);

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

plt.subplots_adjust(wspace=0.2, hspace=0.5)

df["A"].plot(ax=axes[0, 0]);

axes[0, 0].set_title("A");

df["B"].plot(ax=axes[0, 1]);

axes[0, 1].set_title("B");

df["C"].plot(ax=axes[1, 0]);

axes[1, 0].set_title("C");

df["D"].plot(ax=axes[1, 1]);
axes[1, 1].set_title("D");

# %% [markdown]
# ## Plotting with error bars
# ---

# %% [markdown]
# ## Plotting tables
# ---

# %%
fig, ax = plt.subplots(1, 1, figsize=(7, 6.5))
df = pd.DataFrame(np.random.rand(5, 3), columns=["a", "b", "c"])
ax.xaxis.tick_top()
df.plot(table=True, ax=ax);

# %%
fig, ax = plt.subplots(1, 1, figsize=(7, 6.75))
ax.xaxis.tick_top()
df.plot(table=np.round(df.T, 2), ax=ax);

# %%
from pandas.plotting import table
fig, ax = plt.subplots(1,1)
table(ax, np.round(df.describe(), 2), loc="upper right", colWidths=[0.2,0.2,0.4])
df.plot(ax=ax, ylim=(0,2), legend=None)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Colormaps
# ---

# %%
df = pd.DataFrame(np.random.randn(1000, 10), index=ts.index)
df = df.cumsum()
plt.figure()
df.plot(colormap='gist_rainbow')
# Out:
# <AxesSubplot:>
